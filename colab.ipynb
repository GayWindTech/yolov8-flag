# %%
# !git clone https://github.com/GayWindTech/yolov8-flag
# !cd yolov8-flag/ultralytics/
# !wget https://apps.ystone.top:3030/disk-2/AI/datasets.zip
# !unzip datasets.zip
# Out:
# fatal: destination path 'yolov8-flag' already exists and is not an empty directory.
# --2023-07-15 10:36:42--  https://apps.ystone.top:3030/disk-2/AI/datasets.zip
# Resolving apps.ystone.top (apps.ystone.top)... 125.92.110.53
# Connecting to apps.ystone.top (apps.ystone.top)|125.92.110.53|:3030... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 296891287 (283M) [application/zip]
# Saving to: ‘datasets.zip’
#
# datasets.zip        100%[===================>] 283.14M  12.6MB/s    in 22s
#
# 2023-07-15 10:37:05 (12.8 MB/s) - ‘datasets.zip’ saved [296891287/296891287]

# %%
# Out:
# Archive:  datasets.zip
#   inflating: flag.yaml
#    creating: flag/
#    creating: flag/images/
#    creating: flag/images/test/
#   inflating: flag/images/test/01-002.jpg
#   inflating: flag/images/test/01-006.jpg
#   inflating: flag/images/test/01-009.jpg
#   inflating: flag/images/test/01-015.jpg
#   inflating: flag/images/test/01-029.jpg
#   inflating: flag/images/test/01-032.jpg
#   inflating: flag/images/test/01-033.jpg
#   inflating: flag/images/test/01-042.jpg
#   inflating: flag/images/test/01-047.jpg
#   inflating: flag/images/test/01-056.jpg
#   inflating: flag/images/test/01-057.jpg
#   inflating: flag/images/test/01-062.jpg
#   inflating: flag/images/test/01-064.jpg
#   inflating: flag/images/test/01-077.jpg
#   inflating: flag/images/test/01-079.jpg
#   inflating: flag/images/test/01-081.jpg
#   inflating: flag/images/test/01-087.jpg
#   inflating: flag/images/test/01-099.jpg
#   inflating: flag/images/test/01-103.jpg
#   inflating: flag/images/test/01-105.jpg
# ...
